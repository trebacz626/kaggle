# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

from sklearn.model_selection import cross_val_score,train_test_split
from sklearn.linear_model import LinearRegression

from myDataTools import *

# %%
all_data = pd.read_csv('data/diamonds.csv')
all_data = all_data.drop('Unnamed: 0',axis=1)
all_data['cut'] = all_data['cut'].astype('category')
all_data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
prepare_missing_summary(all_data)
# Out:
#          Total  Percentage
# z            0         0.0
# y            0         0.0
# x            0         0.0
# price        0         0.0
# table        0         0.0
# depth        0         0.0
# clarity      0         0.0
# color        0         0.0
# cut          0         0.0
# carat        0         0.0

# %%
# for col in all_data.columns:
#     all_data[col].hist()
#     plt.title(col)
#     plt.show()
# sns.distplot(all_data, hist=True, kde=False,
#              bins=int(180/5), color = ['darkblue']*10, 
#              hist_kws={'edgecolor':'black'})
all_data.hist(column=all_data.columns, figsize=[15,15])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8fb59657d0>,
# ...
#       dtype=object)

# %%
y=all_data['price']
for col in all_data.columns.copy().re

# %%
all_data['color'] = all_data['color'].map({'D':7,'E':6,'F':5,'G':4,'H':3,'I':2,'J':1})
all_data['cut'] = all_data['cut'].map({'Fair':1,'Good':2,'Very Good':3,'Premium':4,'Ideal':5})
all_data['clarity'] = all_data['clarity'].map({'I1':1,'SI2':2,'SI1':3,'VS2':4,'VS1':5,'VVS2':6,'VVS1':7,'IF':8})
all_data.head()
